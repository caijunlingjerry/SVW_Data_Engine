# %%
#Project B：产品关联分析
#现在需要你使用Apriori算法，挖掘订单中的频繁项集及关联规则
#数据源：产品表.csv，订单表.csv，客户.csv，日期表.csv

import pandas as pd
import time
# 数据加载
data = pd.read_csv('./订单表.csv',encoding='gbk')
df = data[['客户ID', '产品名称']].sort_values('客户ID')

#print(df)
hot_encoded_df=data.groupby(['客户ID','产品名称'])['产品名称'].count().unstack().reset_index().fillna(0).set_index('客户ID')
#print(hot_encoded_df)


# 采用efficient_apriori工具包
def rule1 ( ):
	from efficient_apriori import apriori
	start = time.time ( )
	# 得到一维数组orders_series，并且将Transaction作为index, value为Item取值
	orders_series = df.set_index ( '客户ID' )['产品名称']
	# 将数据集进行格式转换
	transactions = []
	temp_index = 0
	for i, v in orders_series.items ( ):
		if i != temp_index:
			temp_set = set ( )
			temp_index = i
			temp_set.add ( v )
			transactions.append ( temp_set )
		else:
			temp_set.add ( v )
		# 挖掘频繁项集和频繁规则
	itemsets, rules = apriori ( transactions, min_support=0.02, min_confidence=0.5 )
	print ( 'efficient_apriori频繁项集1：', itemsets )
	print ( 'efficient_apriori关联规则1：', rules )

	end = time.time ( )
	print ( "用时：", end - start )

def encode_units (x):
	if x <= 0:
		return 0
	if x >= 1:
		return 1

# 采用mlxtend.frequent_patterns工具包
def rule2 ( ):
	from mlxtend.frequent_patterns import apriori
	from mlxtend.frequent_patterns import association_rules
	pd.options.display.max_columns = 100
	start = time.time ( )
	hot_encoded_df = df.groupby ( ['客户ID', '产品名称'] )['产品名称'].count ( ).unstack ( ).reset_index ( ).fillna (
		0 ).set_index ( '客户ID' )
	#print ( hot_encoded_df )
	hot_encoded_df = hot_encoded_df.applymap ( encode_units )
	frequent_itemsets = apriori ( hot_encoded_df, min_support=0.03, use_colnames=True )
	rules = association_rules ( frequent_itemsets, metric="lift", min_threshold=0.5 )
	print ( "mlxtend频繁项集2：", frequent_itemsets )
	print ( "mlxtend关联规则2：", rules[(rules['lift'] >= 1) & (rules['confidence'] >= 0.5)] )
	# print(rules['confidence'])
	end = time.time ( )
	#print ( "用时：", end - start )

if __name__ == '__main__':
	rule1 ( )
	print ( '-' * 100 )
	rule2 ( )
# Out:
# efficient_apriori频繁项集1： {1: {('车胎和内胎',): 8490, ('头盔',): 5960, ('山地自行车',): 4089, ('旅行自行车',): 2143, ('挡泥板',): 2110, ('骑行服',): 3192, ('水壶和水壶架',): 4548, ('帽子',): 2132, ('公路自行车',): 6397, ('手套',): 1376, ('袜子',): 559, ('短裤',): 1019, ('水袋背包',): 719, ('清洁剂',): 875, ('背心',): 557}, 2: {('头盔', '山地自行车'): 1388, ('头盔', '挡泥板'): 742, ('头盔', '旅行自行车'): 1058, ('头盔', '车胎和内胎'): 2921, ('头盔', '骑行服'): 923, ('山地自行车', '挡泥板'): 898, ('山地自行车', '旅行自行车'): 1246, ('山地自行车', '车胎和内胎'): 1107, ('山地自行车', '骑行服'): 679, ('挡泥板', '车胎和内胎'): 723, ('挡泥板', '骑行服'): 493, ('旅行自行车', '车胎和内胎'): 529, ('旅行自行车', '骑行服'): 406, ('车胎和内胎', '骑行服'): 1150, ('公路自行车', '头盔'): 2051, ('公路自行车', '山地自行车'): 2053, ('公路自行车', '帽子'): 673, ('公路自行车', '挡泥板'): 493, ('公路自行车', '水壶和水壶架'): 1590, ('公路自行车', '骑行服'): 1154, ('头盔', '帽子'): 678, ('头盔', '水壶和水壶架'): 1453, ('山地自行车', '帽子'): 511, ('山地自行车', '水壶和水壶架'): 1246, ('帽子', '水壶和水壶架'): 746, ('帽子', '骑行服'): 689, ('挡泥板', '水壶和水壶架'): 524, ('水壶和水壶架', '骑行服'): 774, ('帽子', '旅行自行车'): 414, ('帽子', '车胎和内胎'): 760, ('旅行自行车', '水壶和水壶架'): 780, ('水壶和水壶架', '车胎和内胎'): 812, ('头盔', '手套'): 687, ('手套', '车胎和内胎'): 677, ('手套', '水壶和水壶架'): 419, ('手套', '骑行服'): 380, ('短裤', '骑行服'): 374, ('清洁剂', '车胎和内胎'): 540, ('公路自行车', '手套'): 423, ('公路自行车', '旅行自行车'): 550, ('公路自行车', '车胎和内胎'): 1450}, 3: {('头盔', '山地自行车', '旅行自行车'): 677, ('头盔', '山地自行车', '车胎和内胎'): 388, ('头盔', '车胎和内胎', '骑行服'): 551, ('山地自行车', '旅行自行车', '车胎和内胎'): 402, ('公路自行车', '头盔', '山地自行车'): 726, ('公路自行车', '头盔', '水壶和水壶架'): 477, ('公路自行车', '山地自行车', '挡泥板'): 493, ('公路自行车', '山地自行车', '水壶和水壶架'): 629, ('公路自行车', '山地自行车', '骑行服'): 371, ('头盔', '山地自行车', '水壶和水壶架'): 500, ('山地自行车', '旅行自行车', '水壶和水壶架'): 548, ('头盔', '水壶和水壶架', '车胎和内胎'): 387, ('头盔', '手套', '车胎和内胎'): 394, ('头盔', '帽子', '车胎和内胎'): 375, ('公路自行车', '山地自行车', '车胎和内胎'): 580, ('公路自行车', '头盔', '车胎和内胎'): 410}}
# efficient_apriori关联规则1： [{旅行自行车} -> {山地自行车}, {山地自行车} -> {公路自行车}, {清洁剂} -> {车胎和内胎}, {山地自行车, 旅行自行车} -> {头盔}, {头盔, 旅行自行车} -> {山地自行车}, {头盔, 骑行服} -> {车胎和内胎}, {旅行自行车, 车胎和内胎} -> {山地自行车}, {头盔, 山地自行车} -> {公路自行车}, {山地自行车, 挡泥板} -> {公路自行车}, {公路自行车, 挡泥板} -> {山地自行车}, {山地自行车, 水壶和水壶架} -> {公路自行车}, {山地自行车, 骑行服} -> {公路自行车}, {旅行自行车, 水壶和水壶架} -> {山地自行车}, {手套, 车胎和内胎} -> {头盔}, {头盔, 手套} -> {车胎和内胎}, {头盔, 帽子} -> {车胎和内胎}, {山地自行车, 车胎和内胎} -> {公路自行车}]
# 用时： 0.3081800937652588
# ----------------------------------------------------------------------------------------------------
# mlxtend频繁项集2：      support                itemsets
# 0   0.346083                 (公路自行车)
# 1   0.322441                    (头盔)
# 2   0.221218                 (山地自行车)
# 3   0.115343                    (帽子)
# 4   0.074443                    (手套)
# 5   0.114153                   (挡泥板)
# 6   0.115938                 (旅行自行车)
# 7   0.246051                (水壶和水壶架)
# 8   0.038899                  (水袋背包)
# 9   0.047338                   (清洁剂)
# 10  0.055129                    (短裤)
# 11  0.030134                    (背心)
# 12  0.030242                    (袜子)
# 13  0.459316                 (车胎和内胎)
# 14  0.172690                   (骑行服)
# 15  0.110961             (头盔, 公路自行车)
# 16  0.111069          (山地自行车, 公路自行车)
# 17  0.036410             (帽子, 公路自行车)
# 18  0.086020         (水壶和水壶架, 公路自行车)
# 19  0.078446          (车胎和内胎, 公路自行车)
# 20  0.062432            (骑行服, 公路自行车)
# 21  0.075092             (头盔, 山地自行车)
# 22  0.036680                (头盔, 帽子)
# 23  0.037167                (头盔, 手套)
# 24  0.040143               (头盔, 挡泥板)
# 25  0.057239             (旅行自行车, 头盔)
# 26  0.078609            (水壶和水壶架, 头盔)
# 27  0.158029             (车胎和内胎, 头盔)
# 28  0.049935               (骑行服, 头盔)
# 29  0.048583            (山地自行车, 挡泥板)
# 30  0.067410          (旅行自行车, 山地自行车)
# 31  0.067410         (水壶和水壶架, 山地自行车)
# 32  0.059890          (车胎和内胎, 山地自行车)
# 33  0.036734            (骑行服, 山地自行车)
# 34  0.040359            (水壶和水壶架, 帽子)
# 35  0.041117             (车胎和内胎, 帽子)
# 36  0.037275               (骑行服, 帽子)
# 37  0.036626             (车胎和内胎, 手套)
# 38  0.039115            (车胎和内胎, 挡泥板)
# 39  0.042199         (水壶和水壶架, 旅行自行车)
# 40  0.043930         (水壶和水壶架, 车胎和内胎)
# 41  0.041874           (水壶和水壶架, 骑行服)
# 42  0.062216            (骑行服, 车胎和内胎)
# 43  0.039277      (头盔, 山地自行车, 公路自行车)
# 44  0.034029  (水壶和水壶架, 山地自行车, 公路自行车)
# 45  0.031378   (车胎和内胎, 山地自行车, 公路自行车)
# 46  0.036626      (旅行自行车, 头盔, 山地自行车)
# mlxtend关联规则2：         antecedents consequents  antecedent support  consequent support  \
# 2           (山地自行车)     (公路自行车)            0.221218            0.346083
# 28          (旅行自行车)     (山地自行车)            0.115938            0.221218
# 52      (头盔, 山地自行车)     (公路自行车)            0.075092            0.346083
# 58  (水壶和水壶架, 山地自行车)     (公路自行车)            0.067410            0.346083
# 64   (车胎和内胎, 山地自行车)     (公路自行车)            0.059890            0.346083
# 70      (旅行自行车, 头盔)     (山地自行车)            0.057239            0.221218
# 71   (旅行自行车, 山地自行车)        (头盔)            0.067410            0.322441
#
#      support  confidence      lift  leverage  conviction
# 2   0.111069    0.502079  1.450746  0.034509    1.313294
# 28  0.067410    0.581428  2.628299  0.041762    1.860568
# 52  0.039277    0.523055  1.511356  0.013289    1.371052
# 58  0.034029    0.504815  1.458654  0.010700    1.320552
# 64  0.031378    0.523939  1.513910  0.010652    1.373598
# 70  0.036626    0.639887  2.892556  0.023964    2.162601
# 71  0.036626    0.543339  1.685079  0.014891    1.483723
